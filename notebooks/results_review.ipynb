# %% [markdown]
# # SemiTNet reproduction results
# This notebook reads smoke and paper-reference outputs generated by the repository.

# %%
from pathlib import Path
import json, pandas as pd
ROOT=Path('..').resolve()
smoke=json.loads((ROOT/'outputs/smoke/metrics.json').read_text())
reference=json.loads((ROOT/'paper/reference/paper_targets.json').read_text())
smoke, reference['overall']

# %%
pd.read_csv(ROOT/'paper/reference/table2_overall.csv')
